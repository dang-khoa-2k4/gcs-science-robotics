# %%
# %load_ext autoreload
# %autoreload 2

import os
import shutil
import pickle
import time
import pprint
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull
from IPython.display import SVG

from pydrake.examples import QuadrotorGeometry
from pydrake.geometry import MeshcatVisualizer, Rgba, StartMeshcat
from pydrake.geometry.optimization import HPolyhedron, VPolytope
from pydrake.multibody.plant import AddMultibodyPlantSceneGraph
from pydrake.multibody.parsing import Parser
from pydrake.perception import PointCloud
from pydrake.solvers import MosekSolver
from pydrake.systems.analysis import Simulator
from pydrake.systems.framework import DiagramBuilder

from gcs.bezier import BezierGCS
from reproduction.uav.helpers import FlatnessInverter
from reproduction.uav.building_generation import *
from reproduction.util import *

mosek_license = MosekSolver.AcquireLicense()

# %%
# Start the visualizer (run this cell only once, each instance consumes a port)
meshcat = StartMeshcat()

meshcat.SetProperty("/Grid", "visible", False)
meshcat.SetProperty("/Axes", "visible", False)
meshcat.SetProperty("/Lights/AmbientLight/<object>", "intensity", 0.8)
meshcat.SetProperty("/Lights/PointLightNegativeX/<object>", "intensity", 0)
meshcat.SetProperty("/Lights/PointLightPositiveX/<object>", "intensity", 0)
# Out:
# INFO:drake:Meshcat listening for connections at http://localhost:7001

# %% [markdown]
# # Generate Building and Plan Through

# %%
start = np.array([-1, -1])
goal = np.array([2, 1])
building_shape = (3, 3)
start_pose = np.r_[(start-start)*5, 1.]
goal_pose = np.r_[(goal-start)*5., 1.]

# Generate a random building
np.random.seed(3)
grid, outdoor_edges, wall_edges = generate_grid_world(shape=building_shape, start=start, goal=goal)
regions = compile_sdf(FindModelFile("models/room_gen/building.sdf"), grid, start, goal, outdoor_edges, wall_edges)

# %%
# Build the GCS optimization
gcs = BezierGCS(regions, order=7, continuity=4, hdot_min=1e-3, full_dim_overlap=True)

gcs.addTimeCost(1e-3)
gcs.addPathLengthCost(1)
gcs.addVelocityLimits(-10 * np.ones(3), 10 * np.ones(3))
regularization = 1e-3
gcs.addDerivativeRegularization(regularization, regularization, 2)
gcs.addDerivativeRegularization(regularization, regularization, 3)
gcs.addDerivativeRegularization(regularization, regularization, 4)
gcs.addSourceTarget(start_pose, goal_pose, zero_deriv_boundary=3)

gcs.setPaperSolverOptions()
gcs.setSolver(MosekSolver())

# Solve GCS
trajectory = gcs.SolvePath(True, verbose=False, preprocessing=True)[0]
# Out:
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Problem
# Problem
# Problem
#   Name                   :
#   Name                   :
#   Objective sense        : minimize
#   Name                   :
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
# Presolve started.
#   Objective sense        : minimize
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Affine conic cons.     : 0
#   Matrix variables       : 0
#   Integer variables      : 0
#
#   Integer variables      : 0
#
# Optimizer started.
# Optimizer started.
# Eliminator started.
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Freed constraints in eliminator : 17
# Eliminator terminated.
# Presolve started.
# Presolve started.
# Problem
# Presolve started.
# Problem
#   Name                   :
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
# Eliminator started.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
# Linear dependency checker started.
#   Disjunctive cons.      : 0
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
# Problem
#   Matrix variables       : 0
# Problem
#   Integer variables      : 0
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Name                   :
# Problem
#
#   Cones                  : 0
# Linear dependency checker terminated.
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Name                   :
#   Integer variables      : 0
#   Cones                  : 0
#   Objective sense        : minimize
#   Constraints            : 74
# Eliminator started.
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Type                   : LO (linear optimization problem)
#   Objective sense        : minimize
# Optimizer started.
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Integer variables      : 0
#
# Optimizer started.
# Freed constraints in eliminator : 10
# Eliminator terminated.
#   Constraints            : 74
# Freed constraints in eliminator : 11
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
# Problem
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
# Presolve started.
#   Type                   : LO (linear optimization problem)
#
#   Constraints            : 74
# Optimizer started.
#   Name                   :
#   Objective sense        : minimize
#   Disjunctive cons.      : 0
#
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
#
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Type                   : LO (linear optimization problem)
# Presolve started.
#   Constraints            : 74
#   Affine conic cons.     : 0
# Optimizer started.
#   Cones                  : 0
# Lin. dep.  - primal deps.           : 3                 dual deps.             : 0
# Eliminator started.
#   Name                   :
#   Cones                  : 0
#   Scalar variables       : 124
#   Objective sense        : minimize
#   Scalar variables       : 124
#   Type                   : LO (linear optimization problem)
#   Matrix variables       : 0
# Presolve started.
#   Integer variables      : 0
#   Matrix variables       : 0
# Eliminator started.
#   Integer variables      : 0
#
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Constraints            : 74
# Optimizer started.
# Problem
# Eliminator started.
# Eliminator started.
#
#   Matrix variables       : 0
# Freed constraints in eliminator : 8
# Eliminator terminated.
#   Integer variables      : 0
# Optimizer started.
#
# Optimizer started.
# Presolve started.
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
# Freed constraints in eliminator : 8
#   Affine conic cons.     : 0
# Eliminator terminated.
#   Disjunctive cons.      : 0
# Presolve terminated. Time: 0.00
# Problem
# Presolve started.
#   Affine conic cons.     : 0
# Optimizer started.
# Presolve started.
#   Cones                  : 0
# Freed constraints in eliminator : 12
# Eliminator terminated.
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - primal attempts        : 0                 successes              : 0
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
#   Name                   :
# Presolve terminated. Time: 0.00
# Freed constraints in eliminator : 10
# Linear dependency checker started.
# Eliminator started.
# Eliminator started.
#
# Eliminator started.
# Eliminator started.
# Linear dependency checker terminated.
#   Objective sense        : minimize
# Problem
# Linear dependency checker started.
#   Name                   :
#   Objective sense        : minimize
# Eliminator terminated.
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
# Eliminator terminated.
# Eliminator started.
# Presolve started.
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
# Linear dependency checker terminated.
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Optimizer terminated. Time: 0.00
# Presolve started.
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
# Freed constraints in eliminator : 12
# Eliminator terminated.
# Linear dependency checker started.
# Eliminator started.
#   Integer variables      : 0
#   Type                   : LO (linear optimization problem)
#
# Optimizer started.
# Freed constraints in eliminator : 10
# Eliminator started.
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Optimizer started.
# Freed constraints in eliminator : 22
# Eliminator terminated.
# Eliminator started.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Freed constraints in eliminator : 18
# Eliminator terminated.
# Freed constraints in eliminator : 23
# Eliminator terminated.
# Eliminator started.
#   Dual.    obj: 1.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
# Presolve started.
#
# Basic solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - primal attempts        : 0                 successes              : 0
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal attempts        : 0                 successes              : 0
#   Dual.    obj: 1.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
# Eliminator started.
# Presolve started.
# Freed constraints in eliminator : 10
# Freed constraints in eliminator : 19
# Eliminator terminated.
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Eliminator - tries                  : 1                 time                   : 0.00
# Eliminator terminated.
# Freed constraints in eliminator : 17
# Eliminator terminated.
# Freed constraints in eliminator : 8
# Eliminator terminated.
# Eliminator started.
# Presolve terminated. Time: 0.00
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Eliminator terminated.
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Freed constraints in eliminator : 19
# Linear dependency checker started.
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Freed constraints in eliminator : 10
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Optimizer terminated. Time: 0.00
#
# Lin. dep.  - primal attempts        : 0                 successes              : 0
# Eliminator - tries                  : 1                 time                   : 0.00
# Optimizer  - threads                : 1
# Optimizer terminated. Time: 0.00
# Optimizer  - solved problem         : the primal
#
# Optimizer  - Constraints            : 26
#
# Interior-point solution summary
# Eliminator terminated.
#   Problem status  : PRIMAL_INFEASIBLE
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Lin. dep.  - primal attempts        : 0                 successes              : 0
# Linear dependency checker terminated.
# Presolve terminated. Time: 0.00
#   Solution status : PRIMAL_INFEASIBLE_CER
# Eliminator - tries                  : 1                 time                   : 0.00
#
# Linear dependency checker started.
# Interior-point solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - dual attempts          : 0                 successes              : 0
#   Dual.    obj: 1.0000000000e+00    nrm: 2e+00    Viol.  con: 0e+00    var: 0e+00
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
#
# Basic solution summary
# Eliminator - tries                  : 2                 time                   : 0.00
# Presolve terminated. Time: 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
#   Problem status  : PRIMAL_INFEASIBLE
#   Dual.    obj: 1.0000000000e+00    nrm: 2e+00    Viol.  con: 0e+00    var: 0e+00
#   Solution status : PRIMAL_INFEASIBLE_CER
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Optimizer terminated. Time: 0.00
# Linear dependency checker terminated.
# Optimizer  - Cones                  : 0
#
#   Dual.    obj: 1.0000000000e+00    nrm: 2e+00    Viol.  con: 0e+00    var: 0e+00
#
# Eliminator started.
# Linear dependency checker terminated.
# Interior-point solution summary
# Optimizer  - Scalar variables       : 59                conic                  : 0
#   Problem status  : PRIMAL_INFEASIBLE
# Optimizer terminated. Time: 0.00
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Linear dependency checker started.
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Linear dependency checker started.
# Eliminator started.
#
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00
# Linear dependency checker started.
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - tries                  : 0                 time                   : 0.00
#   Solution status : PRIMAL_INFEASIBLE_CER
# Presolve terminated. Time: 0.00
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Lin. dep.  - primal attempts        : 0                 successes              : 0
#
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Presolve terminated. Time: 0.00
# Linear dependency checker terminated.
# Factor     - nonzeros before factor : 102               after factor           : 129
#
#   Dual.    obj: 1.0000000100e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
# Factor     - dense dim.             : 0                 flops                  : 1.24e+03
# Lin. dep.  - dual attempts          : 0                 successes              : 0
#
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Freed constraints in eliminator : 12
# Basic solution summary
# Basic solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
# Eliminator started.
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   5.2e+00  4.9e-01  3.6e+00  0.00e+00   0.000000000e+00   -3.132707222e+00  4.9e-01  0.00
# Presolve started.
# Presolve terminated. Time: 0.00
# Linear dependency checker terminated.
#   Dual.    obj: 1.0000000000e+00    nrm: 2e+00    Viol.  con: 0e+00    var: 0e+00
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Freed constraints in eliminator : 13
# Eliminator terminated.
# Eliminator started.
# Optimizer terminated. Time: 0.00
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
# Interior-point solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
#   Dual.    obj: 1.0000000100e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
#
# Basic solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
#   Dual.    obj: 1.0000000100e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
#   Dual.    obj: 1.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
#
# Basic solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
# Freed constraints in eliminator : 8
# Eliminator terminated.
# Freed constraints in eliminator : 13
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
#   Dual.    obj: 1.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Eliminator terminated.
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
# Linear dependency checker terminated.
# Eliminator started.
#   Dual.    obj: 1.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
#
# Basic solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
#   Dual.    obj: 1.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
# Problem
#   Name                   :
#   Solution status : PRIMAL_INFEASIBLE_CER
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Freed constraints in eliminator : 15
# Optimizer started.
#   Dual.    obj: 1.0000000100e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
# Eliminator terminated.
# Presolve started.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Eliminator started.
# 1   2.5e+00  2.4e-01  1.7e+00  6.98e+00   0.000000000e+00   3.290004024e-04   2.3e-01  0.00
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Freed constraints in eliminator : 6
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Lin. dep.  - tries                  : 0                 time                   : 0.00
# Lin. dep.  - primal attempts        : 0                 successes              : 0
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 0                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Optimizer terminated. Time: 0.00
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
#   Dual.    obj: 1.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
#
# Basic solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
#   Dual.    obj: 1.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
# Presolve started.
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 25
# Eliminator started.
# Optimizer terminated. Time: 0.00
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
# Freed constraints in eliminator : 23
# Eliminator terminated.
#   Dual.    obj: 1.0000000000e+00    nrm: 2e+00    Viol.  con: 0e+00    var: 0e+00
#
# Basic solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
#   Dual.    obj: 1.0000000000e+00    nrm: 2e+00    Viol.  con: 0e+00    var: 0e+00
# 2   5.3e-02  5.1e-03  3.7e-02  1.24e+00   0.000000000e+00   -6.987994609e-03  5.0e-03  0.00
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Linear dependency checker started.
# Presolve started.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Eliminator started.
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 33
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 66                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Problem
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
#   Name                   :
# Linear dependency checker terminated.
# Eliminator started.
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
# Factor     - nonzeros before factor : 115               after factor           : 137
# Factor     - dense dim.             : 0                 flops                  : 1.17e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.0e+00  8.6e-01  2.4e+00  0.00e+00   0.000000000e+00   -1.790824894e+00  6.0e-01  0.00
# Freed constraints in eliminator : 14
# Eliminator terminated.
#   Integer variables      : 0
#
# Optimizer started.
# Freed constraints in eliminator : 9
# Eliminator terminated.
# Presolve started.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
# Presolve started.
# Eliminator started.
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 3                 dual deps.             : 0
# Eliminator terminated.
# Linear dependency checker started.
#   Affine conic cons.     : 0
# Eliminator started.
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Freed constraints in eliminator : 30
# Eliminator terminated.
# Linear dependency checker terminated.
# Optimizer  - threads                : 1
#   Disjunctive cons.      : 0
# Presolve started.
# Eliminator started.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# 3   5.5e-06  5.2e-07  3.8e-06  1.02e+00   0.000000000e+00   -7.144976282e-07  5.2e-07  0.00
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 33
# Presolve terminated. Time: 0.00
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 70                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Linear dependency checker started.
# Eliminator started.
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 124               after factor           : 148
# Factor     - dense dim.             : 0                 flops                  : 1.37e+03
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Freed constraints in eliminator : 12
# Eliminator terminated.
# Freed constraints in eliminator : 16
# Eliminator terminated.
# Optimizer started.
# Linear dependency checker terminated.
# Eliminator started.
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 45                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00
# Presolve started.
# Freed constraints in eliminator : 4
# Eliminator terminated.
# Eliminator started.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Optimizer  - threads                : 1
# 1   2.2e+00  3.1e-01  8.7e-01  5.14e+00   0.000000000e+00   1.954342872e-01   2.2e-01  0.00
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Optimizer  - solved problem         : the primal
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Optimizer  - Constraints            : 33
# Presolve terminated. Time: 0.00
# Freed constraints in eliminator : 23
# Eliminator terminated.
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 64                conic                  : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Freed constraints in eliminator : 29
# Eliminator terminated.
# Optimizer  - threads                : 1
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 37
# Linear dependency checker started.
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 69                conic                  : 0
# Presolve started.
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - setup time             : 0.00
# Linear dependency checker started.
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : LO (linear optimization problem)
#   Constraints            : 74
# Eliminator started.
# Linear dependency checker terminated.
# Factor     - nonzeros before factor : 76                after factor           : 91
# Factor     - dense dim.             : 0                 flops                  : 7.03e+02
# Eliminator started.
# Factor     - nonzeros before factor : 111               after factor           : 133
# Linear dependency checker started.
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Linear dependency checker terminated.
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
# Eliminator started.
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# Factor     - dense dim.             : 0                 flops                  : 1.11e+03
# Factor     - setup time             : 0.00
#   Scalar variables       : 124
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   4.1e+00  4.4e-01  2.0e+00  0.00e+00   0.000000000e+00   -1.604762059e+00  4.3e-01  0.00
# Linear dependency checker terminated.
# Freed constraints in eliminator : 11
# 0   7.3e+00  4.8e-01  2.8e+00  0.00e+00   0.000000000e+00   -2.202589844e+00  6.1e-01  0.00
# Eliminator started.
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Eliminator terminated.
# Factor     - nonzeros before factor : 125               after factor           : 160
# Freed constraints in eliminator : 22
# Eliminator terminated.
# Factor     - dense dim.             : 0                 flops                  : 1.35e+03
# Freed constraints in eliminator : 11
# Eliminator terminated.
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# Freed constraints in eliminator : 4
# Eliminator terminated.
# 0   5.4e+00  6.8e-01  2.6e+00  0.00e+00   0.000000000e+00   -2.162076502e+00  4.6e-01  0.00
# Linear dependency checker started.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Linear dependency checker started.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal deps.           : 3                 dual deps.             : 0
# 4   5.5e-10  5.2e-11  3.8e-10  1.00e+00   0.000000000e+00   -7.144978555e-11  5.2e-11  0.00
# Linear dependency checker terminated.
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 5                 dual deps.             : 0
# 0   3.7e+00  5.3e-01  1.7e+00  0.00e+00   0.000000000e+00   -1.312217343e+00  4.0e-01  0.00
# Presolve terminated. Time: 0.00
# Linear dependency checker terminated.
# Eliminator started.
# Eliminator started.
# 2   1.7e-01  2.4e-02  6.7e-02  1.28e+00   0.000000000e+00   1.015558988e-02   1.7e-02  0.00
# Freed constraints in eliminator : 4
# Eliminator terminated.
# Freed constraints in eliminator : 9
# Eliminator terminated.
# Presolve terminated. Time: 0.00
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 16
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 42                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 64                after factor           : 85
# Factor     - dense dim.             : 0                 flops                  : 8.61e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   5.3e+00  1.0e-01  3.7e+00  0.00e+00   0.000000000e+00   -3.182265082e+00  5.4e-01  0.00
# Basis identification started.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Optimizer  - threads                : 1
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 39
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 81                conic                  : 0
# Eliminator started.
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 150               after factor           : 173
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 39
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 83                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Optimizer  - Constraints            : 16
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 42                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Basis identification initialization started.
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 64                after factor           : 85
# Factor     - dense dim.             : 0                 flops                  : 8.61e+02
# 1   3.2e+00  2.1e-01  1.2e+00  5.29e+00   0.000000000e+00   3.641929063e-02   2.6e-01  0.00
# Freed constraints in eliminator : 12
# Eliminator terminated.
# 1   2.0e+00  2.5e-01  9.8e-01  5.69e+00   0.000000000e+00   1.269499670e-01   1.7e-01  0.00
# Basis identification initialization terminated. Time: 0.00
# Primal basis identification phase started.
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   5.3e+00  1.0e-01  3.7e+00  0.00e+00   0.000000000e+00   -3.182265082e+00  5.4e-01  0.00
# Factor     - dense dim.             : 0                 flops                  : 1.60e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   3.8e+00  7.2e-01  1.8e+00  0.00e+00   0.000000000e+00   -1.343085328e+00  4.1e-01  0.00
# 3   1.1e-04  1.6e-05  4.5e-05  1.02e+00   0.000000000e+00   2.229183073e-06   1.1e-05  0.00
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 150               after factor           : 181
# 1   2.5e+00  4.7e-02  1.8e+00  6.34e+00   0.000000000e+00   -9.779779054e-02  2.5e-01  0.00
# Factor     - dense dim.             : 0                 flops                  : 1.69e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.9e+00  9.5e-01  2.5e+00  0.00e+00   0.000000000e+00   -1.923207692e+00  6.1e-01  0.00
# Linear dependency checker started.
# Primal basis identification phase terminated. Time: 0.00
# Dual basis identification phase started.
# Optimizer  - threads                : 1
# 1   1.1e+00  1.5e-01  4.9e-01  4.69e+00   0.000000000e+00   1.741937079e-01   1.1e-01  0.00
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 22
# Optimizer  - Cones                  : 0
# Linear dependency checker terminated.
# Eliminator started.
# Optimizer  - Scalar variables       : 54                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 88                after factor           : 116
# Factor     - dense dim.             : 0                 flops                  : 1.13e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.1e+00  2.0e-01  4.2e+00  0.00e+00   0.000000000e+00   -3.655642664e+00  5.4e-01  0.00
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# 1   1.3e+00  1.4e-01  6.3e-01  4.42e+00   0.000000000e+00   4.789897806e-02   1.3e-01  0.00
# Optimizer  - Constraints            : 23
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 45                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 79                after factor           : 94
# Factor     - dense dim.             : 0                 flops                  : 8.12e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 16
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 42                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00
# 0   4.7e+00  5.2e-01  2.7e+00  0.00e+00   0.000000000e+00   -2.282155233e+00  4.7e-01  0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 64                after factor           : 85
# Factor     - dense dim.             : 0                 flops                  : 8.61e+02
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   5.3e+00  1.0e-01  3.7e+00  0.00e+00   0.000000000e+00   -3.182265082e+00  5.4e-01  0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 3                 dual deps.             : 0
# Dual basis identification phase terminated. Time: 0.00
# Presolve terminated. Time: 0.00
# 1   2.5e+00  4.7e-02  1.8e+00  6.34e+00   0.000000000e+00   -9.779779054e-02  2.5e-01  0.00
# Initialization.                            Time: 0.00
# Primal.          Iterations: 31            Time: 0.00
# Dual.            Iterations: 1             Time: 0.00
# Optimization.    Iterations: 0             Time: 0.00
# Basis identification terminated. Time: 0.00
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 16
# Optimizer  - Cones                  : 0
# ...
# 3   2.0e-01  3.0e-02  6.6e-02  1.36e+00   0.000000000e+00   -1.739152015e+02  1.7e-02  0.00
# Primal basis identification phase terminated. Time: 0.00
# Dual basis identification phase started.
# Dual basis identification phase terminated. Time: 0.00
# Initialization.                            Time: 0.00
# Primal.          Iterations: 22            Time: 0.00
# Dual.            Iterations: 5             Time: 0.00
# Optimization.    Iterations: 0             Time: 0.00
# Basis identification terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 0.0000000000e+00    nrm: 1e+00    Viol.  con: 2e-10    var: 8e-11
#   Dual.    obj: -3.8174196034e-11   nrm: 5e-01    Viol.  con: 3e-12    var: 2e-11
#
# Basic solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 0.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
#   Dual.    obj: 8.8961005229e-11    nrm: 7e-11    Viol.  con: 4e-11    var: 7e-11
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 33
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 69                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 119               after factor           : 134
# Factor     - dense dim.             : 0                 flops                  : 1.19e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.4e+00  8.8e-01  2.4e+00  0.00e+00   0.000000000e+00   -1.805240854e+00  5.9e-01  0.00
# 4   4.5e-02  6.9e-03  1.5e-02  8.26e+00   0.000000000e+00   1.098418299e+02   3.8e-03  0.00
# 1   2.5e+00  3.4e-01  9.4e-01  5.00e+00   0.000000000e+00   1.510929945e-01   2.3e-01  0.00
# 5   4.9e-06  7.5e-07  1.6e-06  -9.97e-01  0.000000000e+00   1.104389348e+06   4.2e-07  0.00
# 2   1.5e-01  2.0e-02  5.5e-02  1.36e+00   0.000000000e+00   5.626432493e-03   1.4e-02  0.00
# 6   4.9e-10  7.5e-11  1.6e-10  -1.00e+00  0.000000000e+00   1.104389922e+10   4.2e-11  0.01
# Basis identification started.
# Basis identification initialization started.
# Basis identification initialization terminated. Time: 0.00
# Dual basis identification phase started.
# Dual basis identification phase terminated. Time: 0.00
# Initialization.                            Time: 0.00
# Primal.          Iterations: 0             Time: 0.00
# Dual.            Iterations: 37            Time: 0.00
# Optimization.    Iterations: 0             Time: 0.00
# Basis identification terminated. Time: 0.00
# 3   1.1e-04  1.5e-05  4.2e-05  1.02e+00   0.000000000e+00   3.551660364e-06   1.0e-05  0.00
# Optimizer terminated. Time: 0.01
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
#   Dual.    obj: 2.2356477243e+00    nrm: 8e+00    Viol.  con: 7e-12    var: 1e-11
#
# Basic solution summary
#   Problem status  : PRIMAL_INFEASIBLE
#   Solution status : PRIMAL_INFEASIBLE_CER
#   Dual.    obj: 1.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
# 4   1.1e-08  1.5e-09  4.2e-09  1.00e+00   0.000000000e+00   3.551619767e-10   1.0e-09  0.00
# Basis identification started.
# Basis identification initialization started.
# Basis identification initialization terminated. Time: 0.00
# Primal basis identification phase started.
# Primal basis identification phase terminated. Time: 0.00
# Dual basis identification phase started.
# Problem
#   Name                   :
#   Objective sense        : minimize
# Dual basis identification phase terminated. Time: 0.00
#   Type                   : LO (linear optimization problem)
# Initialization.                            Time: 0.00
# Primal.          Iterations: 9             Time: 0.00
# Dual.            Iterations: 11            Time: 0.00
# Optimization.    Iterations: 0             Time: 0.00
# Basis identification terminated. Time: 0.00
#   Constraints            : 74
#   Affine conic cons.     : 0
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 124
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Optimizer terminated. Time: 0.00
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
# Eliminator started.
#   Primal.  obj: 0.0000000000e+00    nrm: 1e+00    Viol.  con: 3e-09    var: 2e-09
#   Dual.    obj: 2.0553277207e-10    nrm: 1e+00    Viol.  con: 1e-10    var: 4e-10
#
# Basic solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 0.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 6e-17
#   Dual.    obj: 7.2337806414e-10    nrm: 8e-10    Viol.  con: 5e-10    var: 4e-10
# Freed constraints in eliminator : 8
# Eliminator terminated.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 12
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 2                 dual deps.             : 0
# Presolve terminated. Time: 0.00
# Optimizer  - threads                : 1
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 39
# Optimizer  - Cones                  : 0
# Optimizer  - Scalar variables       : 81                conic                  : 0
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.00
# Factor     - dense det. time        : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 150               after factor           : 173
# Factor     - dense dim.             : 0                 flops                  : 1.60e+03
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   3.6e+00  6.6e-01  1.8e+00  0.00e+00   0.000000000e+00   -1.399161572e+00  4.0e-01  0.00
# 1   9.5e-01  1.7e-01  4.8e-01  4.74e+00   0.000000000e+00   2.111478400e-01   1.1e-01  0.00
# 2   1.3e-02  2.4e-03  6.5e-03  1.20e+00   0.000000000e+00   1.974713083e-03   1.5e-03  0.00
# 3   1.3e-06  2.5e-07  6.7e-07  1.00e+00   0.000000000e+00   2.012323518e-07   1.5e-07  0.00
# 4   1.3e-10  2.5e-11  6.7e-11  1.00e+00   0.000000000e+00   2.012684724e-11   1.5e-11  0.00
# Basis identification started.
# Basis identification initialization started.
# Basis identification initialization terminated. Time: 0.00
# Primal basis identification phase started.
# Primal basis identification phase terminated. Time: 0.00
# Dual basis identification phase started.
# Dual basis identification phase terminated. Time: 0.00
# Initialization.                            Time: 0.00
# Primal.          Iterations: 16            Time: 0.00
# Dual.            Iterations: 11            Time: 0.00
# Optimization.    Iterations: 0             Time: 0.00
# Basis identification terminated. Time: 0.00
# Optimizer terminated. Time: 0.00
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 0.0000000000e+00    nrm: 1e+00    Viol.  con: 4e-11    var: 2e-11
#   Dual.    obj: 1.6477308425e-11    nrm: 1e+00    Viol.  con: 4e-12    var: 7e-12
#
# Basic solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 0.0000000000e+00    nrm: 1e+00    Viol.  con: 0e+00    var: 0e+00
#   Dual.    obj: 2.1753321366e-11    nrm: 2e-11    Viol.  con: 2e-11    var: 2e-11
# Problem
#   Name                   :
#   Objective sense        : minimize
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 7024
#   Affine conic cons.     : 1110 (4440 rows)
#   Disjunctive cons.      : 0
#   Cones                  : 0
#   Scalar variables       : 3097
#   Matrix variables       : 0
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 2084
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 203
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - primal attempts        : 1                 successes              : 1
# Lin. dep.  - dual attempts          : 0                 successes              : 0
# Lin. dep.  - primal deps.           : 1                 dual deps.             : 0
# Presolve terminated. Time: 0.03
# Optimizer  - threads                : 16
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 6760
# Optimizer  - Cones                  : 1105
# Optimizer  - Scalar variables       : 8622              conic                  : 4505
# Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# Factor     - setup time             : 0.41
# Factor     - dense det. time        : 0.29              GP order time          : 0.05
# Factor     - nonzeros before factor : 8.14e+04          after factor           : 1.73e+05
# Factor     - dense dim.             : 530               flops                  : 6.09e+07
# Factor     - GP saved nzs           : 7.64e+04          GP saved flops         : 2.83e+07
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   1.0e+03  2.7e+00  8.9e+02  0.00e+00   8.370321420e+02   -5.197234842e+01  1.0e+00  0.44
# 1   5.9e+02  1.6e+00  6.8e+02  -9.94e-01  1.423955777e+03   5.391691120e+02   5.9e-01  0.56
# 2   2.6e+02  7.0e-01  4.4e+02  -9.77e-01  3.095086479e+03   2.236975507e+03   2.6e-01  0.61
# 3   1.7e+02  4.6e-01  3.2e+02  -8.30e-01  3.654370240e+03   2.879872256e+03   1.7e-01  0.68
# 4   1.3e+02  3.5e-01  2.1e+02  -3.43e-01  2.542808735e+03   1.937898026e+03   1.3e-01  0.73
# 5   7.1e+01  1.9e-01  8.6e+01  1.91e-01   1.339602046e+03   9.738335124e+02   7.1e-02  0.80
# 6   4.1e+01  1.1e-01  3.6e+01  7.52e-01   7.263857458e+02   5.197156936e+02   4.1e-02  0.86
# 7   1.8e+01  4.8e-02  8.9e+00  1.13e+00   2.924884621e+02   2.151608563e+02   1.8e-02  0.92
# 8   9.1e+00  2.5e-02  3.0e+00  1.32e+00   1.644642562e+02   1.297752681e+02   9.1e-03  0.98
# 9   8.5e+00  2.3e-02  2.8e+00  1.24e+00   1.598612523e+02   1.272897562e+02   8.5e-03  1.04
# 10  5.4e+00  1.5e-02  1.4e+00  1.29e+00   1.192427309e+02   1.001617717e+02   5.4e-03  1.10
# 11  3.9e+00  1.1e-02  8.0e-01  1.25e+00   1.030703818e+02   9.011998092e+01   3.9e-03  1.16
# 12  1.2e+00  3.3e-03  1.3e-01  1.23e+00   7.904274793e+01   7.536016455e+01   1.2e-03  1.22
# 13  8.7e-01  2.4e-03  7.6e-02  1.18e+00   7.686043394e+01   7.435472454e+01   8.7e-04  1.28
# 14  7.7e-01  2.1e-03  6.3e-02  1.10e+00   7.626180829e+01   7.407996265e+01   7.7e-04  1.33
# 15  4.1e-01  1.1e-03  2.4e-02  1.11e+00   7.436520877e+01   7.323955429e+01   4.1e-04  1.39
# 16  2.7e-01  7.4e-04  1.3e-02  1.07e+00   7.379304431e+01   7.304760759e+01   2.7e-04  1.45
# 17  1.3e-01  3.5e-04  4.0e-03  1.07e+00   7.298624328e+01   7.264802813e+01   1.3e-04  1.50
# 18  1.0e-01  2.8e-04  2.8e-03  1.08e+00   7.284653039e+01   7.257923991e+01   1.0e-04  1.56
# 19  2.6e-02  7.0e-05  3.3e-04  1.08e+00   7.242447304e+01   7.236031806e+01   2.6e-05  1.62
# 20  1.2e-02  3.1e-05  9.8e-05  1.02e+00   7.232158221e+01   7.229305130e+01   1.2e-05  1.74
# 21  4.3e-03  1.2e-05  2.2e-05  1.01e+00   7.227446728e+01   7.226386801e+01   4.2e-06  1.80
# 22  2.9e-03  7.8e-06  1.2e-05  9.99e-01   7.226851975e+01   7.226144004e+01   2.7e-06  1.86
# 23  1.1e-03  2.9e-06  2.7e-06  9.98e-01   7.226036225e+01   7.225774358e+01   9.9e-07  1.92
# 24  8.2e-04  2.2e-06  1.8e-06  9.98e-01   7.226013174e+01   7.225811223e+01   7.6e-07  1.97
# 25  2.8e-04  7.5e-07  3.5e-07  9.99e-01   7.225912292e+01   7.225844069e+01   2.5e-07  2.03
# 26  1.9e-04  5.0e-07  1.9e-07  9.99e-01   7.225927357e+01   7.225881424e+01   1.7e-07  2.09
# 27  5.9e-05  1.6e-07  3.4e-08  1.00e+00   7.225951512e+01   7.225936942e+01   5.5e-08  2.15
# 28  4.0e-05  1.1e-07  1.9e-08  1.00e+00   7.225968506e+01   7.225958700e+01   3.7e-08  2.21
# 29  1.0e-05  9.0e-08  2.6e-09  1.00e+00   7.226001163e+01   7.225998572e+01   1.0e-08  2.27
# 30  9.6e-06  8.3e-08  2.3e-09  9.96e-01   7.225986817e+01   7.225984435e+01   9.8e-09  2.34
# 31  6.7e-06  5.7e-08  1.3e-09  9.97e-01   7.225941570e+01   7.225939921e+01   7.4e-09  2.40
# 32  4.9e-06  8.2e-08  6.7e-10  9.98e-01   7.225912118e+01   7.225911078e+01   5.1e-09  2.47
# INFO:drake:Solved GCS shortest path using MOSEK with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 8 unique paths, discarded 92 duplicate paths.
# 33  1.5e-06  9.7e-08  1.2e-10  1.00e+00   7.225914946e+01   7.225914633e+01   1.5e-09  2.58
# 34  5.1e-07  3.7e-08  2.8e-11  1.00e+00   7.225916560e+01   7.225916440e+01   5.9e-10  2.64
# Optimizer terminated. Time: 2.65
#
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: 7.2259165598e+01    nrm: 1e+03    Viol.  con: 9e-02    var: 0e+00    acc: 3e-03
#   Dual.    obj: 7.2259164393e+01    nrm: 4e+02    Viol.  con: 1e-09    var: 1e-06    acc: 6e-16
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 17
#      14 gcs.setSolver(MosekSolver())
#      16 # Solve GCS
# ---> 17 trajectory = gcs.SolvePath(True, verbose=False, preprocessing=True)[0]
#
# File ~/code/motion-planning/gcs-science-robotics/gcs/bezier.py:318, in BezierGCS.SolvePath(self, rounding, verbose, preprocessing)
#     317 def SolvePath(self, rounding=False, verbose=False, preprocessing=False):
# --> 318     best_path, best_result, results_dict = self.solveGCS(
#     319         rounding, preprocessing, verbose)
#     321     if best_path is None:
#     322         return None, results_dict
#
# File ~/code/motion-planning/gcs-science-robotics/gcs/base.py:291, in BaseGCS.solveGCS(self, rounding, preprocessing, verbose)
#     288 elif rounding:
#     289     self.options.max_rounded_paths = 10
# --> 291     rounded_result = self.gcs.SolveShortestPath(self.source, self.target, self.options)
#     292     best_path = MipPathExtraction(self.gcs, rounded_result, self.source, self.target)[0]
#     293     best_result = rounded_result
#
# RuntimeError: Y is not positive semidefinite. It has an eigenvalue -8.407755971720112e-12 that is less than the tolerance -2.220446049250313e-16.

# %% [markdown]
# # Visualized Trajectory

# %%
view_regions = False
track_uav = False

# Build and run Diagram
builder = DiagramBuilder()
plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)

parser = Parser(plant, scene_graph)
parser.package_map().Add("gcs", GcsDir())
model_id = parser.AddModelFromFile(FindModelFile("models/room_gen/building.sdf"))

plant.Finalize()

meshcat_cpp = MeshcatVisualizer.AddToBuilder(builder, scene_graph, meshcat)


animator = meshcat_cpp.StartRecording()
if not track_uav:
    animator = None
traj_system = builder.AddSystem(FlatnessInverter(trajectory, animator))
quad = QuadrotorGeometry.AddToBuilder(builder, traj_system.get_output_port(0), scene_graph)

diagram = builder.Build()

# Set up a simulator to run this diagram
simulator = Simulator(diagram)
simulator.set_target_realtime_rate(1.0)

meshcat.Delete()

if view_regions:
    for ii in range(len(regions)):
        v = VPolytope(regions[ii])
        meshcat.SetTriangleMesh("iris/region_" + str(ii), v.vertices(),
                                ConvexHull(v.vertices().T).simplices.T, Rgba(0.698, 0.67, 1, 0.4))
        
# Simulate
end_time = trajectory.end_time()
simulator.AdvanceTo(end_time+0.05)
meshcat_cpp.PublishRecording()

# %%
with open (os.path.join(GcsDir(), "data/uav_example/trajectory.html"), "w") as f:
    f.write(meshcat.StaticHtml())
